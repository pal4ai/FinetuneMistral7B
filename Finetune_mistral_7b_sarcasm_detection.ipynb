# %% [markdown]
#  # Notebook to finetune Mistral 7B for sarcasm detection

# %% [markdown]
# ## Install necessary libraries

# %%
# !pip install -q -U transformers
# !pip install -q -U accelerate
# !pip install -q -U bitsandbytes
# !pip install -q -U datasets scipy ipywidgets
# !pip install -q -U git+https://github.com/huggingface/peft.git
# !pip install -q bitsandbytes trl peft
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 13.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 41.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 19.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 17.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 20.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 41.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 82.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 43.8 MB/s eta 0:00:00

# %% [markdown]
# ## Import necessary libraries

# %%
import pandas as pd
import numpy as np
import io
from datasets import Dataset
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from peft import prepare_model_for_kbit_training
from peft import LoraConfig, get_peft_model
from peft import AutoPeftModelForCausalLM,PeftConfig
import transformers
from datetime import datetime
from trl import SFTTrainer
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Load Dataset

# %%
column_names_df  = pd.read_csv('/content/drive/MyDrive/Mistral_finetune/Datasets/SarcasmDetection/key.csv',on_bad_lines='skip',encoding='utf-8',sep='\t')
column_names_list = column_names_df.columns
#print(column_names_list)

# %%
train_pd_full = pd.read_csv('/content/drive/MyDrive/Mistral_finetune/Datasets/SarcasmDetection/train-balanced.csv',on_bad_lines='skip',header=None,encoding='utf-8',sep='\t' )
train_pd_full.columns = column_names_list
#train_pd_full

# %%
test_pd_full = pd.read_csv('/content/drive/MyDrive/Mistral_finetune/Datasets/SarcasmDetection/test-balanced.csv',on_bad_lines='skip',header=None,encoding='utf-8',sep='\t' )
test_pd_full.columns = column_names_list
#test_pd_full

# %% [markdown]
# ## Create Data subset for faster training and evaluation

# %%
def create_data_subset(df, sample_size):
  #samplesize - Samples of each label; returns a dataset of 2*samplesize
  # Separate data by label
  df_label_0 = df[df['label'] == 0]
  df_label_1 = df[df['label'] == 1]

  subset_label_0 = df_label_0.sample(sample_size)
  subset_label_1 = df_label_1.sample(sample_size)

  # Combine the subsets
  balanced_subset = pd.concat([subset_label_0, subset_label_1])

  # Shuffle the rows (optional)
  balanced_subset = balanced_subset.sample(frac=1).reset_index(drop=True)
  return balanced_subset

# %%
print('Actual data size of the full train dataframe',train_pd_full.shape)
print('Actual data size of the full test dataframe',test_pd_full.shape)
# Out:
# Actual data size of the full train dataframe (56962, 10)
# Actual data size of the full test dataframe (14452, 10)

# %%
## Number of rows for each label
train_sample_size = 500
train_data_subset = train_pd_full[['label','comment','parent_comment']]
train_data_subset=create_data_subset(train_data_subset,train_sample_size)
print('Data size of the subset train dataframe',train_data_subset.shape)
print('Rows with label:1 ',train_data_subset[train_data_subset['label']==1].shape)
print('Rows with label:0',train_data_subset[train_data_subset['label']==0].shape)
# Out:
# Data size of the subset train dataframe (1000, 3)
# Rows with label:1  (500, 3)
# Rows with label:0 (500, 3)

# %%
## Number of rows for each label
test_sample_size = 50
test_data_subset = test_pd_full[['label','comment','parent_comment']]
test_data_subset=create_data_subset(test_data_subset,test_sample_size)
print('Data size of the subset train dataframe',test_data_subset.shape)
print('Rows with label:1 ',test_data_subset[test_data_subset['label']==1].shape)
print('Rows with label:0',test_data_subset[test_data_subset['label']==0].shape)
# Out:
# Data size of the subset train dataframe (100, 3)
# Rows with label:1  (50, 3)
# Rows with label:0 (50, 3)

# %% [markdown]
# ### Convert pandas dataframe to a dataset

# %%
train_dataset = Dataset.from_pandas(train_data_subset)
test_dataset = Dataset.from_pandas(test_data_subset)
print(train_dataset)
print(test_dataset)
# Out:
# Dataset({
#     features: ['label', 'comment', 'parent_comment'],
#     num_rows: 1000
# })
# Dataset({
#     features: ['label', 'comment', 'parent_comment'],
#     num_rows: 100
# })

# %% [markdown]
# ## LOAD BASE MODEL AND CONFIGs

# %%
## Base model - Pretrained LLM you want to eventually finetune
base_model_name = 'mistralai/Mistral-7B-v0.1'

## Quantization Config
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)
## Load the pretrained model after quantization
model = AutoModelForCausalLM.from_pretrained(base_model_name, quantization_config=bnb_config)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]

# %% [markdown]
# ## TOKENIZATION
# ### Tokenize the input data along with prompt

# %%
## set up tokenizer parameters

tokenizer = AutoTokenizer.from_pretrained(
    base_model_name,
    model_max_length=512,  ## Max Length of input to the model (play around with it may be )
    padding_side="left",
    add_eos_token=True)
tokenizer.pad_token = tokenizer.eos_token

def tokenize(prompt):
    result = tokenizer(
        prompt,
        truncation=True,
        max_length=512, ## Max Length of input to the model (play around with it may be )
        padding="max_length",
    )
    result["labels"] = result["input_ids"].copy()
    return result
# Out:
# tokenizer_config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]

# %% [markdown]
# ## PROMPT GENERATION

# %% [markdown]
# ### Train Prompt

# %%
label_to_text = ["Not Sarcasm", "Sarcasm"]

# %%
def generate_train_prompt(data_point):
    full_prompt =f"""You are a sarcasm detection bot for social media posts. Your task is to assess the comment and its reply and categorize the reply in context of the comment after <<< >>> into one of the following predefined categories:
    Sarcasm
    Not Sarcasm

    ####
    Here are some examples:
    comment: Most of the Bernie people got what they wanted on the platform, or most of it.
    reply: dont trigger them with facts!
    Category: Sarcasm

    comment: The Dallas Morning News: What you need to know about the enemies of the American people the president warned you about
    reply: What a brilliant and well written article that was.
    Category: Not Sarcasm

    If the text doesn't fit into any of the above categories, classify it as:
    Not Sarcasm
    <<<
    comment:
    {data_point["parent_comment"]}
    reply:
    {data_point["comment"]}
    >>>
    Category: {label_to_text[data_point["label"]]}
    """
    return full_prompt

# %% [markdown]
# ### PROMPT ENGINEERING
# #### Evaluating the perforance of a zero shot prompt on test data on pretrained base model

# %% [markdown]
# #### Evaluation Prompt

# %%
## ith example
i=1#72
print("Parent comment: " + train_dataset[i]['parent_comment'])
print("Child comment: " + train_dataset[i]['comment'])
print("Label: " + str(train_dataset[i]['label']) + "\n")
# Out:
# Parent comment: next speaker, please
# Child comment: Yea, shouldn't this rando black guy be in jail?
# Label: 1

# %%
def generate_eval_prompt(data_point):
    full_prompt =f"""You are a sarcasm detection bot for social media posts. Your task is to assess the comment and its reply and categorize the reply in context of the comment after <<< >>> into one of the following predefined categories:
    Sarcasm
    Not Sarcasm

    ####
    Here are some examples:
    comment: Most of the Bernie people got what they wanted on the platform, or most of it.
    reply: dont trigger them with facts!
    Category: Sarcasm

    comment: The Dallas Morning News: What you need to know about the enemies of the American people the president warned you about
    reply: What a brilliant and well written article that was.
    Category: Not Sarcasm

    If the text doesn't fit into any of the above categories, classify it as:
    Not Sarcasm
    <<<
    comment:
    {data_point["parent_comment"]}
    reply:
    {data_point["comment"]}
    >>>
    Catgeory:
    """
    return full_prompt

# %% [markdown]
# #### Testing

# %%
## ith example
i=40
print("Parent comment: " + test_dataset[i]['parent_comment'])
print("Child comment: " + test_dataset[i]['comment'])
print("Label: " + str(test_dataset[i]['label']) + "\n")
# Out:
# Parent comment: They detest political correctness; just don't call them NAZIS
# Child comment: hey, that might hurt their feelings!
# Label: 1

# %%
eval_prompt = generate_eval_prompt(test_dataset[i])
model_input = tokenizer(eval_prompt, return_tensors="pt").to("cuda")
model.eval()
with torch.no_grad():
    print(tokenizer.decode(model.generate(**model_input, max_new_tokens=256, pad_token_id=2)[0], skip_special_tokens=True))

# %% [markdown]
# #### Tokenize the prompts

# %%
def generate_and_tokenize_train_prompt(data_point):
  return {'text':generate_train_prompt(data_point)}

def generate_and_tokenize_eval_prompt(data_point):
  return{'text':generate_eval_prompt(data_point)}

# %% [markdown]
# ## EVALUATION LOOP - FEW SHOT PROMPT ENGINEERING ON BASE MODEL

# %%
n= len(test_dataset)
print(n)
basemodel_results_df= pd.DataFrame(columns=['model_raw_op'])
for i in tqdm(range(n)):
  eval_prompt = generate_eval_prompt(test_dataset[i])
  model_input = tokenizer(eval_prompt, return_tensors="pt").to("cuda")
  model.eval()
  with torch.no_grad():
    decoded_op=tokenizer.decode(model.generate(**model_input, max_new_tokens=256, pad_token_id=2)[0], skip_special_tokens=True)
    basemodel_results_df.loc[i]= [decoded_op]
# Out:
# 100
#   0%|          | 0/100 [00:00<?, ?it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|          | 1/100 [00:21<35:48, 21.70s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 2/100 [00:42<34:39, 21.22s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 3/100 [01:03<34:02, 21.06s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▍         | 4/100 [01:24<33:31, 20.95s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▌         | 5/100 [01:45<33:19, 21.04s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▌         | 6/100 [02:06<33:06, 21.13s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 7/100 [02:27<32:40, 21.08s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 8/100 [02:48<32:14, 21.03s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   9%|▉         | 9/100 [03:09<31:41, 20.89s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  10%|█         | 10/100 [03:30<31:29, 20.99s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  11%|█         | 11/100 [03:51<31:04, 20.95s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  12%|█▏        | 12/100 [04:12<30:45, 20.97s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  13%|█▎        | 13/100 [04:33<30:22, 20.95s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  14%|█▍        | 14/100 [04:54<30:05, 20.99s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  15%|█▌        | 15/100 [05:15<29:40, 20.94s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  16%|█▌        | 16/100 [05:35<29:15, 20.89s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  17%|█▋        | 17/100 [05:56<28:48, 20.83s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  18%|█▊        | 18/100 [06:17<28:22, 20.76s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  19%|█▉        | 19/100 [06:38<28:06, 20.82s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  20%|██        | 20/100 [06:59<27:48, 20.85s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  21%|██        | 21/100 [07:19<27:26, 20.85s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  22%|██▏       | 22/100 [07:40<27:05, 20.84s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  23%|██▎       | 23/100 [08:01<26:43, 20.82s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  24%|██▍       | 24/100 [08:22<26:19, 20.78s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  25%|██▌       | 25/100 [08:42<25:55, 20.74s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  26%|██▌       | 26/100 [09:03<25:41, 20.83s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  27%|██▋       | 27/100 [09:24<25:16, 20.77s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  28%|██▊       | 28/100 [09:45<24:56, 20.78s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  29%|██▉       | 29/100 [10:06<24:37, 20.81s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  30%|███       | 30/100 [10:26<24:13, 20.76s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  31%|███       | 31/100 [10:47<23:53, 20.77s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  32%|███▏      | 32/100 [11:08<23:40, 20.89s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  33%|███▎      | 33/100 [11:09<16:25, 14.71s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  34%|███▍      | 34/100 [11:30<18:14, 16.58s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  35%|███▌      | 35/100 [11:50<19:18, 17.83s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  36%|███▌      | 36/100 [12:11<19:56, 18.69s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  37%|███▋      | 37/100 [12:32<20:20, 19.38s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#
34s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  91%|█████████ | 91/100 [31:39<03:10, 21.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  92%|█████████▏| 92/100 [32:01<02:49, 21.22s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  93%|█████████▎| 93/100 [32:21<02:27, 21.11s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  94%|█████████▍| 94/100 [32:43<02:06, 21.15s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  95%|█████████▌| 95/100 [33:04<01:45, 21.16s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  96%|█████████▌| 96/100 [33:25<01:24, 21.03s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  97%|█████████▋| 97/100 [33:45<01:02, 20.94s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 98/100 [34:06<00:41, 20.86s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▉| 99/100 [34:27<00:20, 20.99s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 100%|██████████| 100/100 [34:48<00:00, 20.89s/it]

# %%
basemodel_results_raw = test_dataset.to_pandas()
basemodel_results_raw['model_raw_op'] = basemodel_results_df['model_raw_op']

# %%
import os
raw_output_path = "/content/drive/MyDrive/Mistral_finetune/output/basemodel/"
# Option 1: Using os.path.join()
csv_filename = 'raw_basemodel_results.csv'
full_csv_path = os.path.join(raw_output_path, csv_filename)

# Now save the DataFrame to the specified location
basemodel_results_raw.to_csv(full_csv_path, sep='\t', index=False)

# %% [markdown]
# #### Read basemodel_results_raw from folder location if not in session

# %%
basemodel_results_raw[10:20]
# Out:
#     label                                            comment  \
# 10      0  American frogs have toad the line for the gay ...
# 11      0    Anyone got a bunker they'd be willing to share?
# 12      0                                            Revolt.
# 13      0                 I'm sure his best friend is black.
# 14      0  He's off to a great start considering his visi...
# 15      0         Jesus Christ SCOTUS is made up of fossils.
# 16      0  lol, can't answer question, gets triggered, st...
# 17      1                                 You're just racist
# 18      1  Yeah, we could all really come together if a p...
# 19      1  If the government would just get out the way a...
#
#                                        parent_comment  \
# 10                            Ribbit for his pleasure
# 11  Donald Trump to be handed nuclear codes despit...
# 12  Wealthy Would Get Billions in Tax Cuts Under O...
# 13  Mississippi lawmaker under fire for claiming '...
# 14  Basically saying let's reduce poverty by slash...
# 15  The next President is not going to appoint a C...
# 16  Keep copy pasting the same shit, I'm sure it h...
# 17  It's also worth noting that Republicans won bi...
# 18  Good both parties should be smashed up into ti...
# 19  But the free market will solve those money iss...
#
#                                          model_raw_op
# 10  You are a sarcasm detection bot for social med...
# 11  You are a sarcasm detection bot for social med...
# 12  You are a sarcasm detection bot for social med...
# 13  You are a sarcasm detection bot for social med...
# 14  You are a sarcasm detection bot for social med...
# 15  You are a sarcasm detection bot for social med...
# 16  You are a sarcasm detection bot for social med...
# 17  You are a sarcasm detection bot for social med...
# 18  You are a sarcasm detection bot for social med...
# 19  You are a sarcasm detection bot for social med...

# %%
test_ip = basemodel_results_raw['model_raw_op'][13]
print(test_ip)
# Out:
# You are a sarcasm detection bot for social media posts. Your task is to assess the comment and its reply and categorize the reply in context of the comment after <<< >>> into one of the following predefined categories:
#     Sarcasm
#     Not Sarcasm
#
#     ####
#     Here are some examples:
#     comment: Most of the Bernie people got what they wanted on the platform, or most of it.
#     reply: dont trigger them with facts!
#     Category: Sarcasm
#
#     comment: The Dallas Morning News: What you need to know about the enemies of the American people the president warned you about
#     reply: What a brilliant and well written article that was.
#     Category: Not Sarcasm
#
#     If the text doesn't fit into any of the above categories, classify it as:
#     Not Sarcasm
#     <<<
#     comment:
#     Mississippi lawmaker under fire for claiming 'all the blacks' in his town get food stamps, don't work
#     reply:
#     I'm sure his best friend is black.
#     >>>
#     Catgeory:
#
#     Not Sarcasm
#
#     <<<
#     comment:
#     The only thing that matters is that the president is a racist.
#     reply:
#     I'm sure his best friend is black.
#     >>>
#     Category:
#     Sarcasm
#
#     <<<
#     comment:
#     The only thing that matters is that the president is a racist.
#     reply:
#     I'm sure his best friend is black.
#     >>>
#     Category:
#     Not Sarcasm
#
#     <<<
#     comment:
#     The only thing that matters is that the president is a racist.
#     reply:
#     I'm sure his best friend is black.
#     >>>
#     Category:
#     Sarcasm
#
#     <<<
#     comment:
#     The only thing that matters is that the president is a racist.
#     reply:
#     I'm sure his best friend is black.
#     >>>
#     Category:
#     Not Sarcasm
#
#     <<<
#     comment:
#     The only thing that matters is that the president is a racist.
#     reply:
#     I'm sure his best friend is black.

# %% [markdown]
# ### Preprocessing function to retrieve output category from LLM output

# %%
def find_first_word_basemodel(text):
    """
    Finds the first word in the input text after removing leading spaces and newlines.
    Returns the first word or None if no word is found.
    """
    # Search for the specified string
    start_index = text.find(">>>\n    Catgeory:")
    if start_index == -1:
        return None  # String not found

    # Extract the substring after the specified string
    remaining_text = text[start_index + len(">>>\n    Catgeory:"):]

    # Remove leading spaces and newlines
    cleaned_text = remaining_text.lstrip()
    #print('cleaned_text',cleaned_text)
    # Find the first word
    words = cleaned_text.split()
    #print('words',words)
    if words:
      if words[0]=='Sarcasm':
        return 'Sarcasm'
      elif words[0]=='Not':
        return 'Not Sarcasm'
      else:
        return 'None'
    else:
        return None  # No word found

# %%
# Example usage:
result = find_first_word_basemodel(test_ip)
print('The output is --->',result)  # Output: "Sarcasm"
# Out:
# The output is ---> Not Sarcasm

# %%
basemodel_results_raw["predicted_category"] = basemodel_results_raw["model_raw_op"].apply(find_first_word_basemodel)

# %%
def text_to_binary(text):
  if text=='Sarcasm':
    return 1
  elif text=='Not Sarcasm':
    return 0
  else:
    return 2

# %%
basemodel_results_raw["predicted_category_bn"] =basemodel_results_raw["predicted_category"].apply(text_to_binary)

# %%
basemodel_results_raw
# Out:
#     label                                            comment  \
# 0       1  Carson: The black guy my preacher said we were...
# 1       1  Yeah, a rich, white WASPy *wo*man is totally d...
# 2       1  Yeah, this study was obviously a plot to distr...
# 3       0               Because only sith deal in absolutes.
# 4       0      I'd like to read about that, is there a link?
# ..    ...                                                ...
# 95      1  Yes, It's a giant conspiracy to take 3 delegat...
# 96      1  No, when these tribes conquered lands they ass...
# 97      1               You're right we should be terrified.
# 98      0                       Because it's an Internet bet
# 99      1  No you obviously didn't grow up there because ...
#
#                                        parent_comment  \
# 0   Dr. Ben Carson surges into 2nd place in Iowa P...
# 1   Ever since her listening tour in 1999 where sh...
# 2                           Don't forget BENGHAZI!!!!
# 3    Why is opposing Trump's agenda "America hating"?
# 4   Yeah that's sad. They're wrong about that. But...
# ..                                                ...
# 95  The mainstream media is lying about this whole...
# 96  Did any of these tribes ethnically cleanse and...
# 97  Keep that sense of righteousness strong, you'l...
# 98                    Only $10? Why not $100 or $500?
# 99  White people don't know what its like to live ...
#
#                                          model_raw_op predicted_category  \
# 0   You are a sarcasm detection bot for social med...            Sarcasm
# 1   You are a sarcasm detection bot for social med...            Sarcasm
# 2   You are a sarcasm detection bot for social med...            Sarcasm
# 3   You are a sarcasm detection bot for social med...            Sarcasm
# 4   You are a sarcasm detection bot for social med...            Sarcasm
# ..                                                ...                ...
# 95  You are a sarcasm detection bot for social med...               None
# 96  You are a sarcasm detection bot for social med...            Sarcasm
# 97  You are a sarcasm detection bot for social med...            Sarcasm
# 98  You are a sarcasm detection bot for social med...        Not Sarcasm
# 99  You are a sarcasm detection bot for social med...            Sarcasm
#
#     predicted_category_bn
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# 4                       1
# ..                    ...
# 95                      2
# 96                      1
# 97                      1
# 98                      0
# 99                      1
#
# [100 rows x 6 columns]

# %%
basemodel_results_raw["predicted_category_bn"].value_counts()
# Out:
# predicted_category_bn
# 1    69
# 2    19
# 0    12
# Name: count, dtype: int64

# %% [markdown]
# ### Evaluation metrics on base model results

# %%
import os
raw_output_path = "/content/drive/MyDrive/Mistral_finetune/output/basemodel/"
# Option 1: Using os.path.join()
csv_filename = 'processed_basemodel_results.csv'
full_csv_path = os.path.join(raw_output_path, csv_filename)

# Now save the DataFrame to the specified location
basemodel_results_raw.to_csv(full_csv_path, sep='\t', index=False)

# %%
from sklearn.metrics import classification_report

# Example ground truth and predicted labels
y_true = basemodel_results_raw['label']
y_pred = basemodel_results_raw['predicted_category_bn']

# Define target names (optional)
#target_names = ['class 0', 'class 1', 'class 2']

# Generate the classification report
report = classification_report(y_true, y_pred)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.16      0.26        50
#            1       0.54      0.74      0.62        50
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.45       100
#    macro avg       0.40      0.30      0.29       100
# weighted avg       0.60      0.45      0.44       100
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## FINETUNE SECTION

# %%
tokenized_train_dataset = train_dataset.map(generate_and_tokenize_train_prompt)
tokenized_train_dataset=tokenized_train_dataset.remove_columns(['label','comment','parent_comment'])
# Out:
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
# based on config
training_args = transformers.TrainingArguments(
    fp16=False, # specify bf16=True instead when training on GPUs that support bf16
    do_eval=False,
    bf16=False,
    optim="paged_adamw_8bit",
    #evaluation_strategy="epoch",
    gradient_accumulation_steps=8,
    #gradient_checkpointing=True,
    #gradient_checkpointing_kwargs={"use_reentrant": False},
    learning_rate=2.0e-05,
    log_level="info",
    weight_decay=0.001,
    logging_steps=10,
    logging_strategy="steps",
    lr_scheduler_type="constant",
    # max_steps=1000000,
    num_train_epochs=4,
    output_dir=output_dir,
    overwrite_output_dir=True,
    per_device_eval_batch_size=1, # originally set to 8
    per_device_train_batch_size=1, # originally set to 8
    # push_to_hub=True,
    # hub_model_id="zephyr-7b-sft-lora",
    # hub_strategy="every_save",
    # report_to="tensorboard",
    save_strategy="steps",
    save_steps=1000,
    seed=42,
    warmup_ratio=0.3
)

# based on config
config = LoraConfig(
    r=8,
    lora_alpha=16,
    target_modules=[
        "q_proj",
        "k_proj",
        "v_proj",
        "o_proj",
        "gate_proj",
        "up_proj",
        "down_proj",
        "lm_head",
    ],
    bias="none",
    lora_dropout=0.05,  # Conventional
    task_type="CAUSAL_LM",
)


trainer = SFTTrainer(
        model=model,
        #model_init_kwargs=model_kwargs,
        args=training_args,
        train_dataset=tokenized_train_dataset,
        #eval_dataset=eval_dataset,
        dataset_text_field="text",
        tokenizer=tokenizer,
        packing=False,
        peft_config=config,
        max_seq_length=512
    )
trainer.train()
# Out:
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:318: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(
# max_steps is given, it will override any value given in num_train_epochs
# After training we make sure to retrieve back the original forward pass method
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1857                 hf_hub_utils.enable_progress_bars()
#    1858         else:
# -> 1859             return inner_training_loop(
#    1860                 args=args,
#    1861                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2201
#    2202                 with self.accelerator.accumulate(model):
# -> 2203                     tr_loss_step = self.training_step(model, inputs)
#    2204
#    2205                 if (
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in training_step(self, model, inputs)
#    3145                 scaled_loss.backward()
#    3146         else:
# -> 3147             self.accelerator.backward(loss)
#    3148
#    3149         return loss.detach() / self.args.gradient_accumulation_steps
#
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py in backward(self, loss, **kwargs)
#    2011             self.scaler.scale(loss).backward(**kwargs)
#    2012         else:
# -> 2013             loss.backward(**kwargs)
#    2014
#    2015     def set_trigger(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     520                 inputs=inputs,
#     521             )
# --> 522         torch.autograd.backward(
#     523             self, gradient, retain_graph, create_graph, inputs=inputs
#     524         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     264     # some Python versions print out the first line of a multi-line function
#     265     # calls in the traceback and some print out the last line
# --> 266     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267         tensors,
#     268         grad_tensors_,
#
# KeyboardInterrupt:

# %% [markdown]
# ## LOAD FINETUNED MODEL CHECKPOINTS

# %% [markdown]
# #### Checkpoint after 2nd epoch

# %%
## Model after epoch 1
project = "run_1"
base_model_name = "mistral"
run_name = base_model_name + "-" + project
checkpoint = 'checkpoint-2000'#'checkpoint-1000'
output_dir = "/content/drive/MyDrive/Mistral_finetune/finetuned_models" + run_name

peft_model_path_1 = output_dir+'/'+checkpoint
print(peft_model_path_1)
ft_model_ep1 = AutoPeftModelForCausalLM.from_pretrained(peft_model_path_1,quantization_config=bnb_config)
# Out:
# /content/drive/MyDrive/Mistral_finetune/finetuned_modelsmistral-run_1/checkpoint-2000
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# eval_prompt = generate_eval_prompt(test_dataset[i])
# model_input = tokenizer(eval_prompt, return_tensors="pt").to("cuda")
# ft_model_ep1.eval()
# with torch.no_grad():
#     print(tokenizer.decode(ft_model_ep1.generate(**model_input, max_new_tokens=256, pad_token_id=2)[0], skip_special_tokens=True))

# %% [markdown]
# ## EVALUATION LOOP

# %%
from tqdm import tqdm

# %% [markdown]
# ### Write the evaluation result in a new column of test dataset along with existing columns - label, comment and parent_comment

# %%
n= len(test_dataset)
print(n)
finetuned_results_df= pd.DataFrame(columns=['model_raw_op'])
for i in tqdm(range(n)):
  eval_prompt = generate_eval_prompt(test_dataset[i])
  model_input = tokenizer(eval_prompt, return_tensors="pt").to("cuda")
  ft_model_ep1.eval()
  with torch.no_grad():
    decoded_op=tokenizer.decode(ft_model_ep1.generate(**model_input, max_new_tokens=256, pad_token_id=2)[0], skip_special_tokens=True)
    finetuned_results_df.loc[i]= [decoded_op]
# Out:
# 100
#   0%|          | 0/100 [00:00<?, ?it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|          | 1/100 [00:35<58:22, 35.38s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 2/100 [01:10<57:40, 35.31s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 3/100 [01:45<57:05, 35.31s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▍         | 4/100 [02:21<56:40, 35.42s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▌         | 5/100 [02:56<55:49, 35.26s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▌         | 6/100 [03:31<55:14, 35.26s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 7/100 [04:07<54:47, 35.35s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 8/100 [04:42<54:07, 35.30s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   9%|▉         | 9/100 [05:17<53:31, 35.29s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  10%|█         | 10/100 [05:52<52:51, 35.23s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  11%|█         | 11/100 [06:28<52:24, 35.33s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  12%|█▏        | 12/100 [07:04<52:01, 35.47s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  13%|█▎        | 13/100 [07:39<51:25, 35.47s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  14%|█▍        | 14/100 [08:15<50:46, 35.43s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  15%|█▌        | 15/100 [08:50<50:19, 35.53s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#
/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  70%|███████   | 70/100 [37:24<11:56, 23.87s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  71%|███████   | 71/100 [37:59<13:08, 27.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  72%|███████▏  | 72/100 [38:35<13:51, 29.71s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  73%|███████▎  | 73/100 [39:10<14:06, 31.36s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  74%|███████▍  | 74/100 [39:45<14:09, 32.67s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  75%|███████▌  | 75/100 [40:21<13:54, 33.39s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  76%|███████▌  | 76/100 [40:56<13:37, 34.06s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  77%|███████▋  | 77/100 [41:32<13:12, 34.45s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  78%|███████▊  | 78/100 [42:07<12:44, 34.75s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  79%|███████▉  | 79/100 [42:42<12:13, 34.91s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  80%|████████  | 80/100 [43:18<11:41, 35.09s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  81%|████████  | 81/100 [43:45<10:23, 32.79s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  82%|████████▏ | 82/100 [44:21<10:04, 33.58s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  83%|████████▎ | 83/100 [44:56<09:38, 34.00s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  84%|████████▍ | 84/100 [45:31<09:09, 34.35s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  85%|████████▌ | 85/100 [46:03<08:24, 33.61s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  86%|████████▌ | 86/100 [46:38<07:56, 34.01s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  87%|████████▋ | 87/100 [47:13<07:26, 34.34s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  88%|████████▊ | 88/100 [47:48<06:55, 34.65s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  89%|████████▉ | 89/100 [48:24<06:23, 34.90s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  90%|█████████ | 90/100 [48:59<05:49, 34.98s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  91%|█████████ | 91/100 [49:34<05:15, 35.01s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  92%|█████████▏| 92/100 [50:09<04:41, 35.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  93%|█████████▎| 93/100 [50:20<03:15, 27.94s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  94%|█████████▍| 94/100 [50:56<03:00, 30.09s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  95%|█████████▌| 95/100 [51:31<02:38, 31.67s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  96%|█████████▌| 96/100 [52:06<02:11, 32.80s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  97%|█████████▋| 97/100 [52:32<01:31, 30.66s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 98/100 [53:07<01:04, 32.02s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▉| 99/100 [53:42<00:32, 32.99s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 100%|██████████| 100/100 [54:18<00:00, 32.58s/it]

# %%
finetuned_results_raw = test_dataset.to_pandas()
finetuned_results_raw['model_raw_op'] = finetuned_results_df['model_raw_op']

# %%
import os
raw_output_path = "/content/drive/MyDrive/Mistral_finetune/output/run1-epoch2/"
# Option 1: Using os.path.join()
csv_filename = 'raw_finetuned_results.csv'
full_csv_path = os.path.join(raw_output_path, csv_filename)

# Now save the DataFrame to the specified location
finetuned_results_raw.to_csv(full_csv_path, sep='\t', index=False)

# %%
finetuned_results_raw

# %% [markdown]
# ## Load raw outputs from finetuned model and fetch the catgeory
# ### - Can be done independently after finetuning and above code need not to be run

# %%
import os
raw_output_path = "/content/drive/MyDrive/Mistral_finetune/output/run1-epoch2/"
# Option 1: Using os.path.join()
csv_filename = 'raw_finetuned_results.csv'
full_csv_path = os.path.join(raw_output_path, csv_filename)

finetuned_results_raw_ip = pd.read_csv(full_csv_path,sep='\t')
finetuned_results_raw_ip
# Out:
#     label                                            comment  \
# 0       1  Carson: The black guy my preacher said we were...
# 1       1  Yeah, a rich, white WASPy *wo*man is totally d...
# 2       1  Yeah, this study was obviously a plot to distr...
# 3       0               Because only sith deal in absolutes.
# 4       0      I'd like to read about that, is there a link?
# ..    ...                                                ...
# 95      1  Yes, It's a giant conspiracy to take 3 delegat...
# 96      1  No, when these tribes conquered lands they ass...
# 97      1               You're right we should be terrified.
# 98      0                       Because it's an Internet bet
# 99      1  No you obviously didn't grow up there because ...
#
#                                        parent_comment  \
# 0   Dr. Ben Carson surges into 2nd place in Iowa P...
# 1   Ever since her listening tour in 1999 where sh...
# 2                           Don't forget BENGHAZI!!!!
# 3    Why is opposing Trump's agenda "America hating"?
# 4   Yeah that's sad. They're wrong about that. But...
# ..                                                ...
# 95  The mainstream media is lying about this whole...
# 96  Did any of these tribes ethnically cleanse and...
# 97  Keep that sense of righteousness strong, you'l...
# 98                    Only $10? Why not $100 or $500?
# 99  White people don't know what its like to live ...
#
#                                          model_raw_op
# 0   You are a sarcasm detection bot for social med...
# 1   You are a sarcasm detection bot for social med...
# 2   You are a sarcasm detection bot for social med...
# 3   You are a sarcasm detection bot for social med...
# 4   You are a sarcasm detection bot for social med...
# ..                                                ...
# 95  You are a sarcasm detection bot for social med...
# 96  You are a sarcasm detection bot for social med...
# 97  You are a sarcasm detection bot for social med...
# 98  You are a sarcasm detection bot for social med...
# 99  You are a sarcasm detection bot for social med...
#
# [100 rows x 4 columns]

# %%
finetuned_results_raw_ip[10:20]

# %%
test_ip = finetuned_results_raw_ip['model_raw_op'][11]
print(test_ip)

# %%
def find_first_word(text):
    """
    Finds the first word in the input text after removing leading spaces and newlines.
    Returns the first word or None if no word is found.
    """
    # Search for the specified string
    start_index = text.find(">>>\n    Catgeory:")
    if start_index == -1:
        return None  # String not found

    # Extract the substring after the specified string
    remaining_text = text[start_index + len(">>>\n    Catgeory:"):]

    # Remove leading spaces and newlines
    cleaned_text = remaining_text.lstrip()
    #print('cleaned_text',cleaned_text)
    # Find the first word
    words = cleaned_text.split()
    #print('words',words)
    if words:
      if words[0]=='Not':
        return 'Not Sarcasm'
      else:
        return words[0]
    else:
        return None  # No word found

# %%
# Example usage:
result = find_first_word(test_ip)
print('The output is --->',result)  # Output: "Sarcasm"
# Out:
# The output is ---> Sarcasm

# %%
finetuned_results_raw_ip["predicted_category"] = finetuned_results_raw_ip["model_raw_op"].apply(find_first_word)

# %%
def text_to_binary(text):
  if text=='Sarcasm':
    return 1
  else:
    return 0

# %%
finetuned_results_raw_ip["predicted_category_bn"] =finetuned_results_raw_ip["predicted_category"].apply(text_to_binary)

# %%
finetuned_results_raw_ip

# %%
import os
raw_output_path = "/content/drive/MyDrive/Mistral_finetune/output/run1-epoch2/"
# Option 1: Using os.path.join()
csv_filename = 'processed_finetuned_results.csv'
full_csv_path = os.path.join(raw_output_path, csv_filename)

# Now save the DataFrame to the specified location
finetuned_results_raw_ip.to_csv(full_csv_path, sep='\t', index=False)

# %%
from sklearn.metrics import classification_report

# Example ground truth and predicted labels
y_true = finetuned_results_raw_ip['label']
y_pred = finetuned_results_raw_ip['predicted_category_bn']

# Define target names (optional)
#target_names = ['class 0', 'class 1', 'class 2']

# Generate the classification report
report = classification_report(y_true, y_pred)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.94      0.82        50
#            1       0.92      0.66      0.77        50
#
#     accuracy                           0.80       100
#    macro avg       0.83      0.80      0.80       100
# weighted avg       0.83      0.80      0.80       100
